# %%
capture_dir = os.path.join(os.getcwd(),"calibrate","gamma","uncorrection_captures")
os.makedirs(capture_dir,exist_ok=True)

# %%
gamma_p = 1.9
with open(os.path.join(os.getcwd(),"calibrate",'gamma.txt'), 'w') as f:
            f.write(str(gamma_p))

# %%
with open(os.path.join(os.getcwd(),"calibrate",'gamma.txt')) as f:
    lines = f.readlines()
float(lines[0])
# Out:
# 1.7

# %%
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager

# driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
# webpath = os.path.join(os.getcwd(),'calibrate.html')
# driver.get(webpath)
# Out:
# ====== WebDriver manager ======
# Current firefox version is 94.0
# Get LATEST geckodriver version for 94.0 firefox
# Driver [C:\Users\mingwucn\.wdm\drivers\geckodriver\win64\v0.30.0\geckodriver.exe] found in cache

# %%
img_num = len(glob.glob(os.path.join(os.getcwd(),"calibrate","gamma","correction_patterns","*.png")))

# %%
os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\*.png")
# Out:
# 'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\*\\*.png'

# %%
glob.glob(os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\\pat{}.png".format("1".zfill(2))))
# Out:
# ['c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\exposure_-1\\pat01.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\exposure_-2\\pat01.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\exposure_-3\\pat01.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\exposure_-4\\pat01.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\exposure_-5\\pat01.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\HDR\\Phase_Shift\\captures\\exposure_-6\\pat01.png']

# %%
list_04 = glob.glob(os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\\pat04.png"))
list_55 = glob.glob(os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\\pat55.png"))
list_42 = glob.glob(os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\\pat42.png"))
list_27 = glob.glob(os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\\pat27.png"))

# %%
i = 0
img_list = glob.glob(os.path.join(os.getcwd(),"HDR","Phase_Shift","captures","*\\pat{}.png".format(str(i).zfill(2))))
images = list(map(cv2.imread,img_list))
times = np.array([1/2,1/4,1/8,1/16,1/32,1/64],dtype=np.float32)
merge_mertens = cv2.createMergeMertens()
res_mertens = merge_mertens.process(images, times)
plt.imshow(res_mertens)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cv2.imshow("a",res_mertens_8bit)
cv2.waitKey()

# %%
res_mertens_8bit = np.clip(res_mertens*255, 0, 255).astype('uint16')
cv2.imwrite(".\\hdr.png",res_mertens_8bit)
plt.imshow(res_mertens_8bit,cmap="Greys")

# %%
images = list(map(cv2.imread,list_27))
merge_debvec = cv2.createMergeDebevec()
times = np.array([1/2,1/4,1/8,1/16,1/32,1/64],dtype=np.float32)

merge_mertens = cv2.createMergeMertens()
res_mertens = merge_mertens.process(images, times)
plt.imshow(res_mertens)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
images = list(map(cv2.imread,list_42))
merge_debvec = cv2.createMergeDebevec()
times = np.array([1/2,1/4,1/8,1/16,1/32,1/64],dtype=np.float32)

merge_mertens = cv2.createMergeMertens()
res_mertens = merge_mertens.process(images, times)
plt.imshow(res_mertens)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
os.listdir(capture_dir)
# Out:
# ['gamma', 'gamma.txt']

# %%
capture_dir = os.path.join(os.getcwd(),"calibrate")#,"HDR","Phase_shift","Generate")
glob.glob(os.path.join(capture_dir,'*{}'.format(".jpg")))
# Out:
# []

# %%
images = list(map(cv2.imread,list_55))
merge_debvec = cv2.createMergeDebevec()
times = np.array([1/2,1/4,1/8,1/16,1/32,1/64],dtype=np.float32)

merge_mertens = cv2.createMergeMertens()
res_mertens = merge_mertens.process(images, times)
plt.imshow(res_mertens)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
images = list(map(cv2.imread,list_04))
merge_debvec = cv2.createMergeDebevec()
times = np.array([1/2,1/4,1/8,1/16,1/32,1/64],dtype=np.float32)

merge_mertens = cv2.createMergeMertens()
res_mertens = merge_mertens.process(images, times)
plt.imshow(res_mertens)

# hdr_debvec = merge_debvec.process(images, times)
# merge_robertson = cv2.createMergeRobertson()
# hdr_robertson = merge_robertson.process(images, times)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
merge_mertens = cv2.createMergeMertens()
res_mertens = merge_mertens.process(images, times)

# %%
tonemap1 = cv2.createTonemapDurand(gamma=2.2)
res_debvec = tonemap1.process(hdr_debvec.copy())
tonemap2 = cv2.createTonemapDurand(gamma=1.3)
res_robertson = tonemap2.process(hdr_robertson.copy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-4166e0bba911> in <module>
# ----> 1 tonemap1 = cv2.createTonemapDurand(gamma=2.2)
#       2 res_debvec = tonemap1.process(hdr_debvec.copy())
#       3 tonemap2 = cv2.createTonemapDurand(gamma=1.3)
#       4 res_robertson = tonemap2.process(hdr_robertson.copy())
#
# AttributeError: module 'cv2' has no attribute 'createTonemapDurand'

# %%
plt.imshow(images[2])

# %%
os.path.splitext([i for i in os.listdir(HDR_dir[0])][1])
# Out:
# ('pat00', '.png')

# %%
code_dir = os.path.join(os.getcwd(),"calibrate","gamma","correction_patterns")

# %%
capture_dir = os.path.join(
    os.getcwd(),
    "HDR","Phase_shift",
    "captures",
    "exposure_{}".format(-1)
    )
# Out:
# ['camera2display.csv',
#  'pat00.png',
#  'pat01.png',
#  'pat02.png',
#  'pat03.png',
#  'pat04.png',
#  'pat05.png',
#  'pat06.png',
#  'pat07.png',
#  'pat08.png',
#  'pat09.png',
#  'pat10.png',
#  'pat11.png',
#  'pat12.png',
#  'pat13.png',
#  'pat14.png',
#  'pat15.png',
#  'pat16.png',
#  'pat17.png',
#  'pat18.png',
#  'pat19.png',
#  'pat20.png',
#  'pat21.png',
#  'pat22.png',
#  'pat23.png',
#  'pat24.png',
#  'pat25.png',
#  'pat26.png',
#  'pat27.png',
#  'pat28.png',
#  'pat29.png',
#  'pat30.png',
#  'pat31.png',
#  'pat32.png',
#  'pat33.png',
#  'pat34.png',
#  'pat35.png',
#  'pat36.png',
#  'pat37.png',
#  'pat38.png',
#  'pat39.png',
#  'pat40.png',
#  'pat41.png',
#  'pat42.png',
#  'pat43.png',
#  'pat44.png',
#  'pat45.png',
#  'pat46.png',
#  'pat47.png',
#  'pat48.png',
#  'pat49.png',
#  'pat50.png',
#  'pat51.png',
#  'pat52.png',
#  'pat53.png',
#  'pat54.png',
#  'pat55.png',
#  'vizualized.png']

# %%
from lights import *
import structuredlight as sl
import imageio,os,glob
import matplotlib.pyplot as plt
import cv2

current_dir = os.getcwd()
greycode_dir = os.path.join(current_dir,"test","Projector-Camera-Calibration","graycode_pattern")
greycode_list = [i for i in os.listdir(greycode_dir) if os.path.splitext(i)[1]==".png"]
src_path = os.path.join(greycode_dir,greycode_list[0])

cali_path = os.path.join(os.getcwd(),"test","Projector-Camera-Calibration")
img_list = glob.glob(cali_path+'\\output_*\\*42.png')
gamma_cali_path = os.path.join(os.getcwd(),"test","phase-shifting","gamma_correction_patterns_uncorrection")
gamma_gen_path = os.path.join(os.getcwd(),"test","phase-shifting","gamma_pattern")

hori_corner = 12
vertical_corner = 11

# %%
uncalibrate_dir = os.path.join(os.getcwd(),"calibrate","gamma","uncorrection_captures")
calibrate_dir = os.path.join(os.getcwd(),"calibrate","gamma","correction_captures")
uncalibrate_dir = glob.glob(os.path.join(uncalibrate_dir,"*.png"))
calibrate_dir = glob.glob(os.path.join(calibrate_dir,"*.png"))

# %%
# comparision between
f1 = os.path.join(gamma_cali_path,"pat00.png")
f2 = os.path.join(gamma_gen_path,"pat00.png")
ft1 = os.path.join(gamma_cali_path,"pat06.png")
ft2 = os.path.join(gamma_gen_path,"pat06.png")
delta_f0 = comparision(f1,f2)
delta_ft = comparision(ft1,ft2)

# %%
# comparision between
plt.figure(dpi=300,figsize=(5,4))
plt.imshow(cv2.imread(f1),cmap="Greys")
plt.colorbar()
plt.savefig(".\\gamma_f1.png",dpi=300)
plt.show()

plt.figure(dpi=300,figsize=(5,4))
plt.imshow(cv2.imread(f2),cmap="Greys")
plt.colorbar()
plt.savefig(".\\gamma_f2.png",dpi=300)
plt.show()

plt.figure(dpi=300,figsize=(5,4))
plt.imshow(delta_f0,cmap="Greys")
plt.colorbar()
plt.savefig(".\\gamma_dif0.png",dpi=300)
plt.show()

# comparision between
plt.figure(dpi=300,figsize=(5,4))
plt.imshow(cv2.imread(ft1),cmap="Greys")
plt.colorbar()
plt.savefig(".\\gamma_ft1.png",dpi=300)
plt.show()

plt.figure(dpi=300,figsize=(5,4))
plt.imshow(cv2.imread(ft2),cmap="Greys")
plt.colorbar()
plt.savefig(".\\gamma_ft2.png",dpi=300)
plt.show()

plt.figure(dpi=300,figsize=(5,4))
plt.imshow(delta_ft,cmap="Greys")
plt.colorbar()
plt.savefig(".\\gamma_dift.png",dpi=300)
plt.show()

# %%
# Out:
# 54

# %%
hori_corner = 12
vertical_corner = 11
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((vertical_corner*hori_corner,3), np.float32)
objp[:,:2] = np.mgrid[0:hori_corner,0:vertical_corner].T.reshape(-1,2)
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.
# images = glob.glob('./calibration/*.png')
images = img_list[:]
for fname in images:
    # print(fname)
    img = cv2.imread(fname)
    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Find the chess board corners
    contrast = apply_brightness_contrast(grey,brightness=100,contrast=100)
    ret, corners = cv2.findChessboardCorners(contrast, (hori_corner,vertical_corner), None)
    # If found, add object points, image points (after refining them)
    if ret == True:
        print(fname)
        objpoints.append(objp)
        corners2 = cv2.cornerSubPix(grey,corners, (11,11), (-1,-1), criteria)
        imgpoints.append(corners)
        # Draw and display the corners
        cv2.drawChessboardCorners(img, (hori_corner,vertical_corner), corners2, ret)
        # cv2.imshow('img', img)
        cv2.imwrite(os.path.join(".\\calibration\\chessboard"+"_".join(fname.split("\\")[-2:])),img)
        key = cv2.waitKey(1000)
        # if key & 0xFF == ord('q'):
        #     continue
# cv2.destroyAllWindows()

ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, grey.shape[::-1], None, None)
# Out:
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\test\Projector-Camera-Calibration\output_1\capture_42.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\test\Projector-Camera-Calibration\output_2\capture_42.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\test\Projector-Camera-Calibration\output_4\capture_42.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\test\Projector-Camera-Calibration\output_5\capture_42.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\test\Projector-Camera-Calibration\output_6\capture_42.png

# %%
img_list
# Out:
# ['c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_1\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_2\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_4\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_5\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_6\\capture_42.png']

# %%
for fname in img_list:
    img = cv2.imread(fname)
    h,  w = img.shape[:2]
    newcameramtx, roi = cv2.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))
    # undistort
    dst = cv2.undistort(img, mtx, dist, None, newcameramtx)
    # crop the image
    x, y, w, h = roi
    dst = dst[y:y+h, x:x+w]
    cv2.imwrite(os.path.join(".\\calibration\\calibrated_"+"_".join(fname.split("\\")[-2:])),dst)

# %%
cam_cali_path = (os.path.join(os.getcwd(),"cam_calibration"))
img_list = glob.glob(cam_cali_path+"\\*.png")
hori_corner = 7
vertical_corner = 5
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((vertical_corner*hori_corner,3), np.float32)
objp[:,:2] = np.mgrid[0:hori_corner,0:vertical_corner].T.reshape(-1,2)
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.
# images = glob.glob('./calibration/*.png')
images = img_list[:]
for fname in images:
    print(fname)
    img = cv2.imread(fname)
    grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Find the chess board corners
    contrast = apply_brightness_contrast(grey,brightness=100,contrast=100)
    ret, corners = cv2.findChessboardCorners(contrast, (hori_corner,vertical_corner), None)
    # If found, add object points, image points (after refining them)
    if ret == True:
        print(fname)
        objpoints.append(objp)
        corners2 = cv2.cornerSubPix(grey,corners, (11,11), (-1,-1), criteria)
        imgpoints.append(corners)
        # Draw and display the corners
        cv2.drawChessboardCorners(img, (hori_corner,vertical_corner), corners2, ret)
        # cv2.imshow('img', img)
        cv2.imwrite(os.path.join(".\\cam_calibrated\\chessboard"+"_".join(fname.split("\\")[-2:])),img)
        key = cv2.waitKey(1000)
        # if key & 0xFF == ord('q'):
        #     continue
# cv2.destroyAllWindows()

ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, grey.shape[::-1], None, None)

fname = img_list[4]
img = cv2.imread(fname)
h,  w = img.shape[:2]
newcameramtx, roi = cv2.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))
# undistort
dst = cv2.undistort(img, mtx, dist, None, newcameramtx)
# crop the image
x, y, w, h = roi
dst = dst[y:y+h, x:x+w]
cv2.imwrite(os.path.join(".\\cam_calibrated\\calibrated_"+"_".join(fname.split("\\")[-2:])),dst)
# Out:
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\1050.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\1200.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\1350.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\150.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\1500.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\1650.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\450.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\600.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\750.png
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\cam_calibration\900.png
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-8717b98d4ff2> in <module>
#      34 # cv2.destroyAllWindows()
#      35
# ...

# %%
img0 = cv2.imread(img_list[2])
grey0 = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)
img_list[2]
# Out:
# 'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_3\\capture_42.png'

# %%
white_img = cv2.imread(".\\test\Projector-Camera-Calibration\\Figure_1.png",cv2.IMREAD_GRAYSCALE)
img =  cv2.imread(".\\test\Projector-Camera-Calibration\\Figure_1.png")
grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
contrast0 = apply_brightness_contrast(grey0,brightness=100,contrast=100)
contrast1 = apply_brightness_contrast(white_img,brightness=100,contrast=100)
contrast2 = apply_brightness_contrast(grey,brightness=100,contrast=100)
plt.figure()
plt.imshow(img0,cmap="Greys")
plt.figure()
plt.imshow(contrast0,cmap="Greys")

# %%
cv2.findChessboardCorners(contrast0, (hori_corner,vertical_corner), None)
# Out:
# (False, None)

# %%
img = cv2.imread(img_list[1])
grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(grey,cmap="Greys")

# %%
plt.imshow(apply_brightness_contrast(grey,brightness=90,contrast=90),cmap="Greys")

# %%
ret, corners = cv2.findChessboardCorners(grey, (hori_corner,vertical_corner), None)

# %%
plt.imshow(grey,cmap="Greys")

# %%
calibrate_cam(img_list)
# Out:
# ['c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_3\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_4\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_5\\capture_42.png',
#  'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\output_6\\capture_42.png']

# %%
pro_cam_calibrate(wait_time=1)
# Out:
# Initializing camera
# Setting camera mode

# %%
calibrate(cam_id=0,capture=True)
# Out:
# Initializing camera
# Setting camera mode
# Start capture
# Move the chessboard: 1/12
# Move the chessboard: 2/12
# Move the chessboard: 3/12
# Move the chessboard: 4/12
# Move the chessboard: 5/12
# Move the chessboard: 6/12
# Move the chessboard: 7/12
# Move the chessboard: 8/12
# Move the chessboard: 9/12
# Move the chessboard: 10/12
# Move the chessboard: 11/12
# Start calibration
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-34b252de5a46> in <module>
# ----> 1 calibrate(cam_id=0,capture=True)
#
# c:\Users\mingwucn\OneDrive\Work\ADAVI\code\lights.py in calibrate(capture, exp_val, fps, cam_id)
#     142     cv2.destroyAllWindows()
#     143
# --> 144     ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)
#     145
#     146     img = cv2.imread('left12.jpg')
#
# ...

# %%
imlist = Pattern(fps=0.2,width=1280,height=800).Binary()

# %%
# calibreation capture
import cv2
cam_id=1
fps=30
exp_val = -6

print("Initializing camera")
camera = cv2.VideoCapture(cam_id)
codec = 0x47504A4D # MJPG
print("Setting camera mode")
camera.set(cv2.CAP_PROP_FPS, fps)
camera.set(cv2.CAP_PROP_FOURCC, codec)
camera.set(cv2.CAP_PROP_FRAME_WIDTH, 4024)
camera.set(cv2.CAP_PROP_FRAME_HEIGHT, 3036)
camera.set(cv2.CAP_PROP_EXPOSURE, exp_val)

print("Start capture")
img_counter = 0
while(True):
    ret,frame = camera.read()
    cv2.imshow('frame',frame)
    key = cv2.waitKey(1)
    if key & 0xFF == ord('q'):
        break
camera.release()
cv2.destroyAllWindows()
# Out:
# Initializing camera
# Setting camera mode
# Start capture

# %%
# load the file
with open("calibration.html") as inf:
    txt = inf.read()
    soup = bs4.BeautifulSoup(txt)

# %%
import tkinter
root = tkinter.Tk()
root.winfo_screenwidth()
# Out:
# 1920

# %%
from fullscreen import FullScreen

screen = FullScreen()

image = cv2.imread(src_path, 1)

screen.imshow(image)

time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e8c6d6f3d87> in <module>
#       3 screen = FullScreen()
#       4
# ----> 5 image = cv2.imread(src_path, 1)
#       6
#       7 screen.imshow(image)
#
# NameError: name 'cv2' is not defined

# %%
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
img = Image.open(src_path)
# showPIL(pilImage)
plt.imshow(img,cmap="Greys")

# %%
import bs4

# load the file
with open("calibration.html") as inf:
    txt = inf.read()
    soup = bs4.BeautifulSoup(txt)
# replace img src
relpath = os.path.relpath(src_path,os.getcwd())
soup.find('img')['src'] = ".\\"+relpath

# save the file again
with open("calibrate.html", "w") as outf:
    outf.write(str(soup))

# %%
capture_dir = os.path.join(current_dir,"test","Projector-Camera-Calibration","capture")

# %%
capture_num = 1
img_name = "graycode{}.png".format(str(img_counter).zfill(2))
img_name = os.path.join(capture_dir,"capture_{}".format(capture_num),img_name)
img_name
# Out:
# 'c:\\Users\\mingwucn\\OneDrive\\Work\\ADAVI\\code\\test\\Projector-Camera-Calibration\\capture\\capture_1\\graycode00.png'

# %%
import cv2
cam_id=1
fps=30
exp_val = -6

print("Initializing camera")
camera = cv2.VideoCapture(cam_id)
codec = 0x47504A4D # MJPG
print("Setting camera mode")
camera.set(cv2.CAP_PROP_FPS, fps)
camera.set(cv2.CAP_PROP_FOURCC, codec)
camera.set(cv2.CAP_PROP_FRAME_WIDTH,1024)
camera.set(cv2.CAP_PROP_FRAME_HEIGHT, 765)
camera.set(cv2.CAP_PROP_EXPOSURE, exp_val)

print("Start capture")
img_counter = 0
while(True):
    ret,frame = camera.read()
    cv2.imshow('frame',frame)
    key = cv2.waitKey(1)
    if key & 0xFF == ord('q'):
        break
camera.release()
cv2.destroyAllWindows()
# Out:
# Initializing camera
# Setting camera mode
# Start capture

# %%
# ajust exposure time
import cv2

print("Initializing camera")

camera = cv2.VideoCapture(1)
print("Setting camera mode")

exp_val = -6

codec = 0x47504A4D # MJPG
camera.set(cv2.CAP_PROP_FPS, 30.0)
camera.set(cv2.CAP_PROP_FOURCC, codec)
camera.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
camera.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)
camera.set(cv2.CAP_PROP_EXPOSURE, exp_val)

print("Starting capture")
i=0
while(1):
    camera.grab()
    retval, im = camera.retrieve(0)
    cv2.imshow("image", im)

    k = cv2.waitKey(1) & 0xff
    if  k == ord('q'):
        print("exit")
        break
    if i%10 == 0:
        cv2.imwrite('./test/video/'+str(i)+'.png',im)

    if i > 120:
        print("Increase exposure time")
        camera.set(cv2.CAP_PROP_EXPOSURE, -2)
    i+=1
camera.release()
cv2.destroyAllWindows()
# Out:
# Initializing camera
# Setting camera mode
# Starting capture
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# Increase exposure time
# exit

# %%
import glob
#棋盘格模板规格
w = 8
h = 6
#存储的点需要是有序的，定义一个网格来存储棋盘格角点的世界坐标和图像坐标对
obj_points = [] # 在世界坐标系中的三维点
img_points = [] # 在图像平面的二维点
images = glob.glob('./calibration/*.png')  #加载图片

for fname in images:
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # 找到棋盘格角点
    ret, corners = cv2.findChessboardCorners(gray, (w,h),None)
    # 如果找到足够点对，将其存储起来
    if ret == True:
        cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)   #亚像素角点检测
        obj_points.append(objp)
        img_points.append(corners)
        # 将角点在图像上显示
        cv2.drawChessboardCorners(img, (w,h), corners, ret)
        cv2.imshow('findCorners',img)
        cv2.waitKey(1)
cv2.destroyAllWindows()

# 标定
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(obj_points, img_points, gray.shape[::-1], None, None)

#将这些值保存到不同的numpy文件中，方便后期加载
np.save("./camera_params/ret", ret)
np.save("./camera_params/K", mtx)
np.save("./camera_params/dist", dist)
np.save("./camera_params/rvecs", rvecs)
np.save("./camera_params/tvecs", tvecs)

print ("ret:",ret)
print ("mtx:\n",mtx)        # 内参数矩阵
print ("dist:\n",dist)      # 畸变系数   distortion cofficients = (k_1,k_2,p_1,p_2,k_3)
print ("rvecs:\n",rvecs)    # 旋转向量  # 外参数
print ("tvecs:\n",tvecs)   # 平移向量  # 外参数

# 去畸变
img2 = cv2.imread('./calibration/150.png')
h,w = img2.shape[:2]
newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),0,(w,h)) # 自由比例参数
dst = cv2.undistort(img2, mtx, dist, None, newcameramtx)

# 根据前面ROI区域裁剪图片
x,y,w,h = roi
dst = dst[y:y+h, x:x+w]
cv2.imwrite('calibresult12.png',dst)
print ("dst的大小为:", dst.shape)

# 计算反投影误差
# 在Python 3中，range()与xrange()合并为range( )
tot_error = 0  
for i in range(len(obj_points)):    
    img_points2, _ = cv2.projectPoints(obj_points[i],rvecs[i],tvecs[i],mtx,dist)  
    error = cv2.norm(img_points[i],img_points2, cv2.NORM_L2)/len(img_points2)  
    tot_error += error  
  
mean_error = tot_error/len(obj_points)  
print ('total error: ', tot_error)  
print ('mean error: ', mean_error)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-43aab0a01cb0> in <module>
#      25
#      26 # 标定
# ---> 27 ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(obj_points, img_points, gray.shape[::-1], None, None)
#      28
#      29 #将这些值保存到不同的numpy文件中，方便后期加载
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-sn_xpupm\opencv\modules\calib3d\src\calibration.cpp:3694: error: (-215:Assertion failed) nimages > 0 in function 'cv::calibrateCameraRO'

# %%
images = glob.glob('*.jpg')
images
# Out:
# []

# %%
import numpy as np
import cv2
import glob

# termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
# Arrays to store object points and image points from all the images.
imgpoints = [] # 2d points in image plane.
images = glob.glob('./calibration/.*.png')

for fname in images:
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    ret = False
    # Find the chess board corners
    ret, corners = cv2.findChessboardCorners(gray, (7,7))
    # If found, add object points, image points (after refining them)
    if ret == True:
        cv2.cornerSubPix(gray, corners, (11,11), (-1,-1), criteria)
        imgpoints.append(corners)
        # Draw and display the corners
        cv2.drawChessboardCorners(img, (7,7), corners, ret)
        cv2.imshow('img',img)
        cv2.waitKey(0)
cv2.destroyAllWindows()
